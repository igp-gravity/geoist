# %%
import math
import json

# %%
# GET /convert
req = json.loads(REQUEST)
args = req['args']

if 'angle' not in args:
    print(json.dumps({'convertedAngle':None}))
else:
    angle = int(args['angle'][0])
    converted = math.readians(angle)
    print(json.dumps({'convertedAngle':converted}))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-042de190433c> in <module>()
#       1 # GET /convert
# ----> 2 req = json.loads(REQUEST)
#       3 args = req['args']
#       4
#       5 if 'angle' not in args:
#
# NameError: name 'REQUEST' is not defined
